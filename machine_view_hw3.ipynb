# %% [markdown]
# ### 下載Fruits360資料集

# %%
import tensorflow as tf
import gc

url = 'https://github.com/Horea94/Fruit-Images-Dataset/archive/master.zip'
name = 'fruits360'
file = tf.keras.utils.get_file(name,url,extract=True)

# %%
import os

# 指定訓練資料夾目錄
training_path = os.path.sep.join(file.split(os.path.sep)[0:-1]+['Fruit-Images-Dataset-master','Training'])

# 指定測試資料夾目錄
test_path     = os.path.sep.join(file.split(os.path.sep)[0:-1]+['Fruit-Images-Dataset-master','Test'])

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing import image
from IPython.display import display
def show_model(model,figsize=(20,20)):
    a = plot_model(model,'models/' + model.name +'.png', show_shapes=True, dpi=300)
    display(a)
    return

# %%
from tensorflow.keras.utils import image_dataset_from_directory

# 訓練資料集
train_dataset = image_dataset_from_directory(training_path,batch_size=32,image_size=(100, 100),validation_split=0.1,shuffle=True,label_mode='categorical',seed=123,subset='training')

# 驗證資料集
validation_dataset = image_dataset_from_directory(training_path,batch_size=32,image_size=(100, 100),validation_split=0.1,shuffle=True,label_mode='categorical',seed=123,subset='validation')

#測試資料集
test_dataset = image_dataset_from_directory(test_path,batch_size=32,label_mode='categorical',image_size=(100, 100))
# Out:
# Found 67692 files belonging to 131 classes.
# Using 60923 files for training.
# Found 67692 files belonging to 131 classes.
# Using 6769 files for validation.
# Found 22688 files belonging to 131 classes.

# %%
import matplotlib.pyplot as plt
test_dataset.take(1)
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 100, 100, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 131), dtype=tf.float32, name=None))>

# %% [markdown]
# ### 定義卷積神經網路架構

# %%
vgg_base = keras.applications.VGG16(include_top=False,weights='imagenet',input_shape=(100, 100, 3))
vgg_base.trainable = False

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.1)
], name='data_augmentation')

# %%
inputs = keras.Input(shape=(100, 100, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = vgg_base(x)
x = layers.Flatten()(x)
x = layers.Dense(512, activation = 'relu')(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(131, activation='softmax')(x)
model = keras.Model(inputs, outputs)

model.summary()
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 100, 100, 3)]     0
#
#  data_augmentation (Sequenti  (None, 100, 100, 3)      0
#  al)
#
#  tf.__operators__.getitem (S  (None, 100, 100, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 100, 100, 3)      0
#
#  vgg16 (Functional)          (None, 3, 3, 512)         14714688
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 512)               2359808
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 131)               67203
#
# =================================================================
# Total params: 17,141,699
# Trainable params: 2,427,011
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ### 訓練卷積神經網路

# %%
transfer_callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath='models/fruit_transfer_model.keras',
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
]

# %%
history = model.fit(train_dataset,epochs=10,validation_data=validation_dataset,callbacks=transfer_callbacks)
# Out:
# Epoch 1/10
# 1904/1904 [==============================] - ETA: 0s - loss: 1.2759 - accuracy: 0.7591
# Epoch 1: val_loss improved from inf to 0.14167, saving model to models/fruit_transfer_model.keras
# 1904/1904 [==============================] - 82s 41ms/step - loss: 1.2759 - accuracy: 0.7591 - val_loss: 0.1417 - val_accuracy: 0.9583
# Epoch 2/10
# 1904/1904 [==============================] - ETA: 0s - loss: 0.6155 - accuracy: 0.8741
# Epoch 2: val_loss improved from 0.14167 to 0.12299, saving model to models/fruit_transfer_model.keras
# 1904/1904 [==============================] - 75s 40ms/step - loss: 0.6155 - accuracy: 0.8741 - val_loss: 0.1230 - val_accuracy: 0.9690
# Epoch 3/10
# 1904/1904 [==============================] - ETA: 0s - loss: 0.5900 - accuracy: 0.8968
# Epoch 3: val_loss improved from 0.12299 to 0.07220, saving model to models/fruit_transfer_model.keras
# 1904/1904 [==============================] - 76s 40ms/step - loss: 0.5900 - accuracy: 0.8968 - val_loss: 0.0722 - val_accuracy: 0.9793
# Epoch 4/10
# 1903/1904 [============================>.] - ETA: 0s - loss: 0.5124 - accuracy: 0.9111
# Epoch 4: val_loss did not improve from 0.07220
# 1904/1904 [==============================] - 75s 39ms/step - loss: 0.5124 - accuracy: 0.9111 - val_loss: 0.0951 - val_accuracy: 0.9789
# Epoch 5/10
# 1903/1904 [============================>.] - ETA: 0s - loss: 0.5267 - accuracy: 0.9224
# Epoch 5: val_loss did not improve from 0.07220
# 1904/1904 [==============================] - 75s 39ms/step - loss: 0.5269 - accuracy: 0.9224 - val_loss: 0.0866 - val_accuracy: 0.9852
# Epoch 6/10
# 1904/1904 [==============================] - ETA: 0s - loss: 0.4817 - accuracy: 0.9292
# Epoch 6: val_loss improved from 0.07220 to 0.03831, saving model to models/fruit_transfer_model.keras
# 1904/1904 [==============================] - 75s 39ms/step - loss: 0.4817 - accuracy: 0.9292 - val_loss: 0.0383 - val_accuracy: 0.9922
# Epoch 7/10
# 1904/1904 [==============================] - ETA: 0s - loss: 0.4871 - accuracy: 0.9364
# Epoch 7: val_loss did not improve from 0.03831
# 1904/1904 [==============================] - 76s 40ms/step - loss: 0.4871 - accuracy: 0.9364 - val_loss: 0.0526 - val_accuracy: 0.9883
# Epoch 8/10
# 1903/1904 [============================>.] - ETA: 0s - loss: 0.4901 - accuracy: 0.9375
# Epoch 8: val_loss did not improve from 0.03831
# 1904/1904 [==============================] - 75s 39ms/step - loss: 0.4900 - accuracy: 0.9375 - val_loss: 0.0547 - val_accuracy: 0.9904
# Epoch 9/10
# 1903/1904 [============================>.] - ETA: 0s - loss: 0.4680 - accuracy: 0.9421
# Epoch 9: val_loss improved from 0.03831 to 0.02794, saving model to models/fruit_transfer_model.keras
# 1904/1904 [==============================] - 75s 39ms/step - loss: 0.4681 - accuracy: 0.9421 - val_loss: 0.0279 - val_accuracy: 0.9948
# Epoch 10/10
# 1903/1904 [============================>.] - ETA: 0s - loss: 0.4716 - accuracy: 0.9430
# Epoch 10: val_loss did not improve from 0.02794
# 1904/1904 [==============================] - 75s 39ms/step - loss: 0.4714 - accuracy: 0.9430 - val_loss: 0.0703 - val_accuracy: 0.9900

# %% [markdown]
# ### 顯示訓練損失歷史曲線

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.history['loss'],label='loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'],label='accuracy')
plt.plot(history.history['val_accuracy'],label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 類神經網路架構圖

# %%
#類神經網路架構
tf.keras.utils.plot_model(model, to_file="neural_architecture1.png")
